# %%
from bs4 import BeautifulSoup
import requests 
import pandas as pd 
headers = {'User Agent':'Mozilla/5.0'}

players = ['paolo-banchero', 'jabari-smith-2', 'chet-holmgren', 'jaden-ivey', 'bennedict-mathurin', 
           'blake-wesley', 'bryce-mcgowens', 'max-christie', 'patrick-baldwinjr', 'tyty-washingtonjr',
           'jalen-duren', 'jonathan-davis-3', 'julian-strawther', 'kendall-brown', 'caleb-houstan', 
           'aminu-mohammed', 'kennedy-chandler', 'keegan-murray', 'wendell-moorejr', 'dereon-seabron',
           'ochai-agbaji', 'mark-williams-7', 'caleb-love', 'trayce-jackson-davis', 'terrence-shannonjr',
           'jamaree-bouyea', 'jaime-jaquezjr', 'johnny-juzang', 'jahvon-quinerly', 'matthew-mayer', 
           'trevor-keels', 'orlando-robinson', 'taevion-kinsey', 'anthony-duruji', 'keon-ellis',
           'julian-champagnie', 'ej-liddell', 'michael-devoe', 'andrew-nembhard', 'oscar-tshiebwe',
           'iverson-molinar', 'jahmir-young', 'tyson-etienne', 'alex-barcello', 'max-abmas', 'kevin-obanor',
           'brady-manek', 'izaiah-brockington', 'moussa-diabate']

player_stats = []
playerlist = []

for player in players:
    try:
        if player[-1].isdigit():
            url = f'https://www.sports-reference.com/cbb/players/{player}.html'
        else:
            url = f'https://www.sports-reference.com/cbb/players/{player}-1.html'
        res = requests.get(url)
        soup = BeautifulSoup(res.content, 'lxml')
        header = [th.getText() for th in soup.findAll('tr', limit = 2)[0].findAll('th')]
        rows = soup.findAll('tr')
        player_stats.append([td.getText() for td in soup.find('tr', id ='players_per_game.2022')])
        table = pd.DataFrame(player_stats, columns = header)
        player = player.replace('-',' ').title()
        if player[-1].isdigit():
            player = player[:-2]
        
        if player[-2:] == 'jr':
            player = player.replace('jr', ' Jr')
        
        playerlist.append(player)
        
    except:
        continue
     
table.insert(0, "Name", playerlist)
table
# Out:
#                     Name   Season             School      Conf   G  GS    MP  \
# 0         Paolo Banchero  2021-22               Duke       ACC  15  15  30.0
# 1           Jabari Smith  2021-22             Auburn       SEC  16  16  26.9
# 2          Chet Holmgren  2021-22            Gonzaga       WCC  15  15  25.0
# 3             Jaden Ivey  2021-22             Purdue   Big Ten  16  16  28.4
# 4     Bennedict Mathurin  2021-22            Arizona    Pac-12  14  14  31.5
# 5           Blake Wesley  2021-22         Notre Dame       ACC  15   9  27.1
# 6         Bryce Mcgowens  2021-22           Nebraska   Big Ten  18  18  33.5
# 7           Max Christie  2021-22     Michigan State   Big Ten  15  15  30.3
# 8     Patrick Baldwin Jr  2021-22          Milwaukee   Horizon   8   7  27.8
# 9     Tyty Washington Jr  2021-22           Kentucky       SEC  16  16  31.4
# 10           Jalen Duren  2021-22            Memphis       AAC  13  13  25.0
# 11        Jonathan Davis  2021-22          Wisconsin   Big Ten  14  14  34.4
# 12      Julian Strawther  2021-22            Gonzaga       WCC  15  15  25.3
# 13         Kendall Brown  2021-22             Baylor    Big 12  16  16  24.6
# 14         Caleb Houstan  2021-22           Michigan   Big Ten  14  14  31.1
# 15        Aminu Mohammed  2021-22         Georgetown  Big East  13  13  30.5
# 16      Kennedy Chandler  2021-22          Tennessee       SEC  14  14  29.9
# 17         Keegan Murray  2021-22               Iowa   Big Ten  15  15  28.9
# 18      Wendell Moore Jr  2021-22               Duke       ACC  15  15  32.6
# 19        Dereon Seabron  2021-22           NC State       ACC  17  17  36.6
# 20          Ochai Agbaji  2021-22             Kansas    Big 12  15  15  33.9
# 21         Mark Williams  2021-22               Duke       ACC  15  15  19.9
# 22            Caleb Love  2021-22                UNC       ACC  15  15  32.4
# 23  Trayce Jackson Davis  2021-22            Indiana   Big Ten  16  16  32.6
# 24   Terrence Shannon Jr  2021-22         Texas Tech    Big 12   6   6  26.3
# 25        Jamaree Bouyea  2021-22      San Francisco       WCC  17  17  34.8
# 26       Jaime Jaquez Jr  2021-22               UCLA    Pac-12  12  12  28.4
# 27         Johnny Juzang  2021-22               UCLA    Pac-12  12  12  30.0
# 28       Jahvon Quinerly  2021-22            Alabama       SEC  16  16  31.7
# 29         Matthew Mayer  2021-22             Baylor    Big 12  15  15  21.5
# 30          Trevor Keels  2021-22               Duke       ACC  15  15  31.3
# 31      Orlando Robinson  2021-22       Fresno State       MWC  16  16  32.1
# 32        Taevion Kinsey  2021-22           Marshall      CUSA  16  16  37.4
# 33        Anthony Duruji  2021-22            Florida       SEC  15  15  24.5
# 34            Keon Ellis  2021-22            Alabama       SEC  16  16  31.6
# 35     Julian Champagnie  2021-22    St. John's (NY)  Big East  13  13  34.3
# 36            Ej Liddell  2021-22         Ohio State   Big Ten  14  14  30.9
# 37         Michael Devoe  2021-22       Georgia Tech       ACC  14  13  35.7
# 38       Andrew Nembhard  2021-22            Gonzaga       WCC  15  15  29.9
# 39        Oscar Tshiebwe  2021-22           Kentucky       SEC  16  16  29.2
# 40       Iverson Molinar  2021-22  Mississippi State       SEC  15  15  32.7
# 41          Jahmir Young  2021-22          Charlotte      CUSA  13  13  36.5
# 42         Tyson Etienne  2021-22      Wichita State       AAC  14  13  33.8
# 43         Alex Barcello  2021-22                BYU       WCC  18  18  30.5
# 44             Max Abmas  2021-22       Oral Roberts    Summit  16  16  34.8
# 45          Kevin Obanor  2021-22         Texas Tech    Big 12  16  16  25.2
# 46           Brady Manek  2021-22                UNC       ACC  15   3  25.8
# 47    Izaiah Brockington  2021-22         Iowa State    Big 12  16  16  33.7
# 48        Moussa Diabate  2021-22           Michigan   Big Ten  13   7  20.8
#
#      FG   FGA   FG%  ...  DRB   TRB  AST  STL  BLK  TOV   PF   PTS      SOS
# 0   6.3  12.7  .492  ...  6.1   7.3  2.2  1.3  0.9  2.1  1.9  17.7     2.76
# 1   5.3  11.6  .457  ...  5.8   6.4  2.1  1.5  1.1  1.8  2.0  16.1     7.45
# 2   4.9   8.0  .617  ...  6.3   8.3  2.1  0.5  3.3  2.1  2.1  13.3     2.23
# 3   5.5  11.0  .500  ...  4.5   5.0  3.1  1.3  0.5  2.2  1.8  16.3     3.55
# 4   6.4  12.6  .508  ...  4.5   6.4  2.1  1.0  0.4  2.1  1.9  18.5     3.50
# 5   5.4  12.2  .443  ...  2.5   3.3  2.1  0.9  0.1  2.4  2.1  14.7     5.18
# 6   4.9  12.5  .396  ...  4.6   5.5  1.6  0.8  0.4  2.0  2.3  15.5     5.24
# 7   3.7   8.9  .414  ...  2.7   3.7  1.7  0.6  0.5  1.5  1.3  10.7     7.15
# 8   4.5  12.1  .371  ...  5.8   6.6  1.8  0.8  0.8  1.9  1.6  13.4    -3.49
# 9   5.7  11.4  .497  ...  3.4   4.3  4.8  1.1  0.3  1.8  1.6  13.7     0.43
# 10  4.2   6.8  .625  ...  4.8   7.1  1.2  0.8  2.7  2.1  2.7  10.3     6.48
# 11  7.7  17.7  .435  ...  6.1   7.5  2.6  1.4  0.7  2.2  1.6  21.7     8.79
# 12  4.9   9.6  .514  ...  4.2   5.8  1.1  0.8  0.1  0.7  1.8  13.5     2.23
# 13  4.6   6.8  .679  ...  2.4   3.8  1.9  1.1  0.3  1.4  2.0  11.0     3.16
# 14  3.0   8.5  .353  ...  3.7   4.5  1.5  0.6  0.4  2.0  1.9   9.2     7.77
# 15  4.8  12.5  .383  ...  5.4   8.3  2.0  1.5  0.5  2.4  2.7  13.8     1.28
# 16  5.1  11.6  .438  ...  2.5   3.1  5.1  2.3  0.4  2.6  1.6  13.4     6.94
# 17  9.1  15.4  .593  ...  5.1   8.0  1.2  1.5  2.1  1.2  1.5  23.9     2.69
# 18  5.8  10.7  .540  ...  4.5   5.8  5.0  1.4  0.1  2.0  1.3  15.4     2.76
# 19  7.4  13.7  .541  ...  6.4   9.6  3.4  1.5  0.1  2.9  1.9  19.8     2.83
# 20  7.6  14.3  .533  ...  3.6   4.6  1.4  0.9  0.3  1.4  1.5  20.6     6.41
# 21  3.8   5.8  .655  ...  3.9   6.3  1.0  0.6  3.1  0.7  2.1   8.6     2.76
# 22  5.3  11.7  .451  ...  3.5   3.7  3.4  1.4  0.2  2.4  1.5  15.6     5.50
# 23  7.5  12.4  .606  ...  6.5   8.9  1.9  0.6  3.1  1.9  1.3  19.3     2.71
# 24  4.8  10.2  .475  ...  2.5   3.2  2.2  1.0  0.2  2.3  1.5  14.3     1.74
# 25  6.7  12.7  .528  ...  4.3   4.8  3.9  1.6  0.9  2.8  1.4  17.8     1.78
# 26  5.1  10.7  .477  ...  3.8   5.6  1.9  1.1  0.3  1.8  1.4  13.3     4.55
# 27  6.4  14.8  .435  ...  4.1   5.0  1.8  0.6  0.2  1.8  2.3  16.6     4.55
# 28  5.8  13.5  .426  ...  3.1   3.6  4.4  0.9  0.2  2.8  1.7  15.4    11.03
# 29  3.4   8.7  .389  ...  3.9   4.9  1.1  1.4  1.1  1.0  2.5   8.6     3.16
# 30  4.3  10.6  .409  ...  2.8   3.6  2.9  1.7  0.0  1.2  1.3  12.1     2.76
# 31  7.1  14.0  .509  ...  5.3   8.4  2.6  1.1  1.5  2.2  1.9  19.8     0.27
# 32  7.2  17.2  .418  ...  2.9   5.3  4.1  0.8  0.0  3.0  1.5  19.9     1.69
# 33  3.5   6.1  .565  ...  2.4   4.2  1.1  1.1  0.9  1.0  2.8   9.1     5.08
# 34  3.8   8.3  .451  ...  4.6   6.3  1.9  1.9  0.6  1.5  2.4  12.1    11.03
# 35  7.8  17.2  .457  ...  5.7   7.3  1.9  1.9  1.4  1.2  1.5  21.2     0.58
# 36  6.6  13.1  .508  ...  4.9   7.1  2.5  0.5  3.0  3.1  2.8  19.9     9.82
# 37  7.2  14.7  .490  ...  4.6   5.4  3.2  1.7  0.6  2.9  2.1  20.5     3.48
# 38  3.5   8.1  .438  ...  2.5   3.0  5.3  1.7  0.2  2.1  1.8   9.1     2.23
# 39  6.9  11.1  .624  ...  9.8  15.1  0.9  1.3  1.4  1.6  2.5  17.0     0.43
# 40  6.1  12.7  .476  ...  2.8   3.4  4.5  1.0  0.5  1.6  1.1  17.5     0.93
# 41  6.9  14.5  .476  ...  5.6   6.2  4.2  0.9  0.5  2.2  0.9  19.8     0.63
# 42  4.9  13.9  .349  ...  1.7   2.2  2.1  1.3  0.1  2.1  2.4  15.0     5.20
# 43  5.3  11.3  .471  ...  3.4   3.7  3.0  0.9  0.0  1.5  2.0  16.8     6.07
# 44  7.6  17.1  .442  ...  3.3   3.4  4.0  1.1  0.1  2.3  1.9  22.9    -2.50
# 45  3.4   7.9  .433  ...  3.9   4.9  0.8  0.4  0.1  1.0  1.8   9.4     1.74
# 46  4.9   9.9  .497  ...  4.5   5.8  1.5  0.5  0.5  1.7  1.3  12.9     5.50
# 47  6.3  12.9  .485  ...  6.1   8.1  1.5  1.3  0.3  1.9  1.7  17.0     3.65
# 48  3.5   5.9  .584  ...  3.7   6.0  0.7  0.4  0.8  1.5  2.2   8.7     7.77
#
# [49 rows x 30 columns]
